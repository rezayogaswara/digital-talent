# %%
import pymysql
import pandas as pd

host = '127.0.0.1'
port = "3306"
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')

def run(sql):
    df = pd.read_sql_query(sql,conn)
    return df

# %% [markdown]
# ## 1. Prepare a list of offices sorted by country, state, city

# %%
run("SELECT * FROM offices ORDER BY country, state, city")
# Out:
#   officeCode           city             phone              addressLine1  \
# 0          6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 1          4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 2          5          Tokyo   +81 33 224 5000               4-1 Kioicho
# 3          7         London  +44 20 7877 2041       25 Old Broad Street
# 4          1  San Francisco   +1 650 219 4782         100 Market Street
# 5          2         Boston   +1 215 837 0825          1550 Court Place
# 6          3            NYC   +1 212 555 3000      523 East 53rd Street
#
#   addressLine2       state    country postalCode territory
# 0     Floor #2        None  Australia   NSW 2010      APAC
# 1         None        None     France      75017      EMEA
# 2         None  Chiyoda-Ku      Japan   102-8578     Japan
# 3      Level 7        None         UK   EC2N 1HN      EMEA
# 4    Suite 300          CA        USA      94080        NA
# ...

# %% [markdown]
# ## 2. How many employees are there in the company?

# %%
run("SELECT COUNT(*) AS numberOfEmployees FROM employees")
# Out:
#    numberOfEmployees
# 0                 23

# %% [markdown]
# ## 3. What is the total of payments received?

# %%
run("SELECT SUM(amount) AS totalOfPaymentsReceived FROM payments")
# Out:
#    totalOfPaymentsReceived
# 0               8853839.23

# %% [markdown]
# ## 4. List the product lines that contain 'Cars'.

# %%
run("""
SELECT 
    *
FROM
    productlines
WHERE
    productLine LIKE '%Cars%'
""")
# Out:
#     productLine                                    textDescription  \
# 0  Classic Cars  Attention car enthusiasts: Make your wildest c...
# 1  Vintage Cars  Our Vintage Car models realistically portray a...
#
#   htmlDescription image
# 0            None  None
# 1            None  None

# %% [markdown]
# ## 5. Report total payments for October 28, 2004.

# %%
run("SELECT SUM(amount) AS totalPaymentsForOctober282004 FROM payments WHERE paymentDate = '2004-10-28'")
# Out:
#    totalPaymentsForOctober282004
# 0                       47411.33

# %% [markdown]
# ## 6. Report those payments greater than \$100,000.

# %%
run("SELECT * FROM payments WHERE amount > 100000")
# Out:
#    customerNumber checkNumber paymentDate     amount
# 0             124    AE215433  2005-03-05  101244.59
# 1             124    KI131716  2003-08-15  111654.40
# 2             141     ID10962  2004-12-31  116208.40
# 3             141    JE105477  2005-03-18  120166.58
# 4             148    KM172879  2003-12-26  105743.00

# %% [markdown]
# ## 7. List the products in each product line.
# ### 7.1. List in 1 output

# %%
run("SELECT * FROM products ORDER BY productLine")
# Out:
#     productCode                                  productName  \
# 0      S10_1949                     1952 Alpine Renault 1300
# 1      S10_4757                          1972 Alfa Romeo GTA
# 2      S10_4962                       1962 LanciaA Delta 16V
# 3      S12_1099                            1968 Ford Mustang
# 4      S12_1108                            2001 Ferrari Enzo
# 5      S12_3148                           1969 Corvair Monza
# 6      S12_3380                           1968 Dodge Charger
# 7      S12_3891                             1969 Ford Falcon
# 8      S12_3990                      1970 Plymouth Hemi Cuda
# 9      S12_4675                           1969 Dodge Charger
# 10     S18_1129                              1993 Mazda RX-7
# 11     S18_1589                        1965 Aston Martin DB5
# 12     S18_1889                  1948 Porsche 356-A Roadster
# 13     S18_1984                             1995 Honda Civic
# ...

# %% [markdown]
# ### 7.2. List in separate output

# %%
run("SELECT productLine FROM productlines")
# Out:
#         productLine
# 0      Classic Cars
# 1       Motorcycles
# 2            Planes
# 3             Ships
# 4            Trains
# 5  Trucks and Buses
# 6      Vintage Cars

# %%
run("SELECT * FROM products WHERE productLine = 'Classic Cars'")
# Out:
#    productCode                          productName   productLine  \
# 0     S10_1949             1952 Alpine Renault 1300  Classic Cars
# 1     S10_4757                  1972 Alfa Romeo GTA  Classic Cars
# 2     S10_4962               1962 LanciaA Delta 16V  Classic Cars
# 3     S12_1099                    1968 Ford Mustang  Classic Cars
# 4     S12_1108                    2001 Ferrari Enzo  Classic Cars
# 5     S12_3148                   1969 Corvair Monza  Classic Cars
# 6     S12_3380                   1968 Dodge Charger  Classic Cars
# 7     S12_3891                     1969 Ford Falcon  Classic Cars
# 8     S12_3990              1970 Plymouth Hemi Cuda  Classic Cars
# 9     S12_4675                   1969 Dodge Charger  Classic Cars
# 10    S18_1129                      1993 Mazda RX-7  Classic Cars
# 11    S18_1589                1965 Aston Martin DB5  Classic Cars
# 12    S18_1889          1948 Porsche 356-A Roadster  Classic Cars
# ...

# %%
run("SELECT * FROM products WHERE productLine = 'Motorcycles'")
# Out:
#    productCode                            productName  productLine  \
# 0     S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
# 1     S10_2016                  1996 Moto Guzzi 1100i  Motorcycles
# 2     S10_4698   2003 Harley-Davidson Eagle Drag Bike  Motorcycles
# 3     S12_2823                       2002 Suzuki XREO  Motorcycles
# 4     S18_2625    1936 Harley Davidson El Knucklehead  Motorcycles
# 5     S18_3782                       1957 Vespa GS150  Motorcycles
# 6     S24_1578                      1997 BMW R 1100 S  Motorcycles
# 7     S24_2000               1960 BSA Gold Star DBD34  Motorcycles
# 8     S24_2360                1982 Ducati 900 Monster  Motorcycles
# 9     S32_1374                       1997 BMW F650 ST  Motorcycles
# 10    S32_2206                      1982 Ducati 996 R  Motorcycles
# 11    S32_4485              1974 Ducati 350 Mk3 Desmo  Motorcycles
# 12    S50_4713                     2002 Yamaha YZR M1  Motorcycles
#
# ...

# %%
run("SELECT * FROM products WHERE productLine = 'Planes'")
# Out:
#    productCode                       productName productLine productScale  \
# 0     S18_1662       1980s Black Hawk Helicopter      Planes         1:18
# 1     S18_2581                    P-51-D Mustang      Planes         1:72
# 2     S24_1785  1928 British Royal Navy Airplane      Planes         1:24
# 3     S24_2841            1900s Vintage Bi-Plane      Planes         1:24
# 4     S24_3949          Corsair F4U ( Bird Cage)      Planes         1:24
# 5     S24_4278           1900s Vintage Tri-Plane      Planes         1:24
# 6    S700_1691       American Airlines: B767-300      Planes        1:700
# 7    S700_2466    America West Airlines B757-200      Planes        1:700
# 8    S700_2834                     ATA: B757-300      Planes        1:700
# 9    S700_3167                F/A 18 Hornet 1/72      Planes         1:72
# 10   S700_4002         American Airlines: MD-11S      Planes        1:700
# 11    S72_1253                  Boeing X-32A JSF      Planes         1:72
#
# ...

# %%
run("SELECT * FROM products WHERE productLine = 'Ships'")
# Out:
#   productCode                productName productLine productScale  \
# 0    S18_3029     1999 Yamaha Speed Boat       Ships         1:18
# 1    S24_2011      18th century schooner       Ships         1:24
# 2   S700_1138      The Schooner Bluenose       Ships        1:700
# 3   S700_1938              The Mayflower       Ships        1:700
# 4   S700_2047                 HMS Bounty       Ships        1:700
# 5   S700_2610  The USS Constitution Ship       Ships        1:700
# 6   S700_3505                The Titanic       Ships        1:700
# 7   S700_3962             The Queen Mary       Ships        1:700
# 8    S72_3212                 Pont Yacht       Ships         1:72
#
#                productVendor  \
# 0            Min Lin Diecast
# 1   Carousel DieCast Legends
# 2      Autoart Studio Design
# 3        Studio M Art Models
# 4       Unimax Art Galleries
# 5          Red Start Diecast
# 6   Carousel DieCast Legends
# 7  Welly Diecast Productions
# 8       Unimax Art Galleries
#
# ...

# %%
run("SELECT * FROM products WHERE productLine = 'Trains'")
# Out:
#   productCode                             productName productLine  \
# 0    S18_3259                Collectable Wooden Train      Trains
# 1    S32_3207  1950's Chicago Surface Lines Streetcar      Trains
# 2    S50_1514          1962 City of Detroit Streetcar      Trains
#
#   productScale             productVendor  \
# 0         1:18  Carousel DieCast Legends
# 1         1:32      Gearbox Collectibles
# 2         1:50   Classic Metal Creations
#
#                                   productDescription  quantityInStock  \
# 0  Hand crafted wooden toy train set is in about ...             6450
# 1  This streetcar is a joy to see. It has 80 sepa...             8601
# 2  This streetcar is a joy to see. It has 99 sepa...             1645
#
#    buyPrice    MSRP
# 0     67.56  100.84
# 1     26.72   62.14
# 2     37.49   58.58

# %%
run("SELECT * FROM products WHERE productLine = 'Trucks and Buses'")
# Out:
#    productCode                                  productName       productLine  \
# 0     S12_1666                               1958 Setra Bus  Trucks and Buses
# 1     S12_4473                            1957 Chevy Pickup  Trucks and Buses
# 2     S18_1097                       1940 Ford Pickup Truck  Trucks and Buses
# 3     S18_2319                       1964 Mercedes Tour Bus  Trucks and Buses
# 4     S18_2432                        1926 Ford Fire Engine  Trucks and Buses
# 5     S18_4600                             1940s Ford truck  Trucks and Buses
# 6     S24_2300                     1962 Volkswagen Microbus  Trucks and Buses
# 7     S32_1268                  1980’s GM Manhattan Express  Trucks and Buses
# 8     S32_2509                  1954 Greyhound Scenicruiser  Trucks and Buses
# 9     S32_3522  1996 Peterbilt 379 Stake Bed with Outrigger  Trucks and Buses
# 10    S50_1392             Diamond T620 Semi-Skirted Tanker  Trucks and Buses
#
# ...

# %%
run("SELECT * FROM products WHERE productLine = 'Vintage Cars'")
# Out:
#    productCode                                productName   productLine  \
# 0     S18_1342                       1937 Lincoln Berline  Vintage Cars
# 1     S18_1367   1936 Mercedes-Benz 500K Special Roadster  Vintage Cars
# 2     S18_1749                   1917 Grand Touring Sedan  Vintage Cars
# 3     S18_2248                         1911 Ford Town Car  Vintage Cars
# 4     S18_2325                  1932 Model A Ford J-Coupe  Vintage Cars
# 5     S18_2795                     1928 Mercedes-Benz SSK  Vintage Cars
# 6     S18_2949                1913 Ford Model T Speedster  Vintage Cars
# 7     S18_2957                         1934 Ford V8 Coupe  Vintage Cars
# 8     S18_3136        18th Century Vintage Horse Carriage  Vintage Cars
# 9     S18_3140                          1903 Ford Model A  Vintage Cars
# 10    S18_3320                   1917 Maxwell Touring Car  Vintage Cars
# 11    S18_3856    1941 Chevrolet Special Deluxe Cabriolet  Vintage Cars
# ...

# %% [markdown]
# ## 8. How many products in each product line?

# %%
run("SELECT productLine, COUNT(*) AS numberOfProducts FROM products GROUP BY productLine")
# Out:
#         productLine  numberOfProducts
# 0      Classic Cars                38
# 1       Motorcycles                13
# 2            Planes                12
# 3             Ships                 9
# 4            Trains                 3
# 5  Trucks and Buses                11
# 6      Vintage Cars                24

# %% [markdown]
# ## 9. What is the minimum payment received?

# %%
run("SELECT MIN(amount) AS minimumPaymentReceived FROM payments")
# Out:
#    minimumPaymentReceived
# 0                  615.45

# %% [markdown]
# ## 10. List all payments greater than twice the average payment.

# %%
run("SELECT * FROM payments WHERE amount > (SELECT AVG(amount) from payments) * 2")
# Out:
#     customerNumber checkNumber paymentDate     amount
# 0              114    MA765515  2004-12-15   82261.22
# 1              124    AE215433  2005-03-05  101244.59
# 2              124    BG255406  2004-08-28   85410.87
# 3              124     ET64396  2005-04-16   83598.04
# 4              124    KI131716  2003-08-15  111654.40
# 5              141     ID10962  2004-12-31  116208.40
# 6              141    IN446258  2005-03-25   65071.26
# 7              141    JE105477  2005-03-18  120166.58
# 8              148    KM172879  2003-12-26  105743.00
# 9              167    GN228846  2003-12-03   85024.46
# 10             239    NQ865547  2004-03-15   80375.24
# 11             321     DJ15149  2003-11-03   85559.12
# 12             323    AL493079  2005-05-23   75020.13

# %% [markdown]
# ## 11. What is the average percentage markup of the MSRP on buyPrice?

# %%
run("SELECT AVG((MSRP - buyPrice) / buyPrice * 100) AS averagePercentageMarkupOfTheMsrpOnBuyPrice FROM products")
# Out:
#    averagePercentageMarkupOfTheMsrpOnBuyPrice
# 0                                   88.702392

# %% [markdown]
# ## 12. How many distinct products does ClassicModels sell?

# %%
run("SELECT COUNT(DISTINCT(productCode)) AS numberOfDistinctProducts FROM products")
# Out:
#    numberOfDistinctProducts
# 0                       110

# %% [markdown]
# ## 13. Report the name and city of customers who don't have sales representatives?

# %%
run("SELECT customerName, city, salesRepEmployeeNumber FROM customers WHERE salesRepEmployeeNumber IS NULL")
# Out:
#                       customerName              city salesRepEmployeeNumber
# 0               Havel & Zbyszek Co          Warszawa                   None
# 1                Porto Imports Co.            Lisboa                   None
# 2       Asian Shopping Network, Co         Singapore                   None
# 3                  Natürlich Autos         Cunewalde                   None
# 4                    ANG Resellers            Madrid                   None
# 5         Messner Shopping Network         Frankfurt                   None
# 6                Franken Gifts, Co           München                   None
# 7                BG&E Collectables          Fribourg                   None
# 8                 Schuyler Imports         Amsterdam                   None
# 9                 Der Hund Imports            Berlin                   None
# 10       Cramer Spezialitäten, Ltd       Brandenburg                   None
# ...

# %% [markdown]
# ## 14. What are the names of executives with VP or Manager in their title? Use the CONCAT function to combine the employee's first name and last name into a single field for reporting.

# %%
run("""
SELECT 
    CONCAT(firstName,' ',lastName) AS namesOfExecutives, jobTitle
FROM
    employees
WHERE
    jobTitle LIKE '%VP%' OR jobTitle LIKE '%Manager%'
""")
# Out:
#    namesOfExecutives              jobTitle
# 0     Mary Patterson              VP Sales
# 1      Jeff Firrelli          VP Marketing
# 2  William Patterson  Sales Manager (APAC)
# 3      Gerard Bondur   Sale Manager (EMEA)
# 4        Anthony Bow    Sales Manager (NA)

# %% [markdown]
# ## 15. Which orders have a value greater than \$5,000?

# %%
run("SELECT *, (quantityOrdered * priceEach) AS value FROM orderdetails WHERE (quantityOrdered * priceEach) > 5000")
# Out:
#      orderNumber productCode  quantityOrdered  priceEach  orderLineNumber  \
# 0          10103    S10_1949               26     214.30               11
# 1          10103    S10_4962               42     119.67                4
# 2          10105    S10_4757               50     127.84                2
# 3          10105    S12_1108               41     205.72               15
# 4          10105    S24_2011               43     117.97                9
# 5          10108    S12_1099               33     165.38                6
# 6          10108    S18_4721               44     139.87               11
# 7          10108    S24_3856               40     132.00                1
# 8          10109    S18_1984               38     137.98                3
# 9          10109    S18_3232               46     160.87                5
# 10         10109    S18_3685               47     125.74                2
# 11         10110    S18_1749               42     153.00                7
# ...
