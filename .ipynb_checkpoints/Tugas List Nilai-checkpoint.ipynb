# %% [markdown]
# # LATIHAN 2 - Tugas List Nilai
#
# Diberikan sekumpulan Nilai Random antara 0 sampai dengan 100 sebanyak 250 nilai. Buatlah program untuk melakukan hal berikut:
# 1. Tampilkan Angka Ganjil dari ke 250 nilai tersebut
# 2. Tampilkan berapa banyak yang mendapatkan nilai lebih dari 70
# 3. Tampilkan standar deviasi dari sekumpulan nilai tersebut
# 4. Tampilkan nilai maksimum dan minimum
# 5. Tampilkan modus dari sekumpulan nilai tersebut

# %%
import random

# GENERATE RANDOM
nilaiTugas = []

for i in range(250):
    nilaiTugas.append(random.randrange(1,100,1))

print(nilaiTugas)

# TAMPILKAN:
# ganjil
nilaiGanjil = []

for g in nilaiTugas:
    if g % 2 != 0 and not(g in nilaiGanjil) :
        nilaiGanjil.append(g)

print()
print('Angka Ganjil dari ke 250 nilai di atas (angka yang sama hanya ditampilkan satu kali ) yaitu :', nilaiGanjil)

# nilai > 70
nilai70Plus = 0

for b in nilaiTugas:
    if b > 70 :
        nilai70Plus += 1

print()
print('Yang mendapatkan nilai lebih dari 70 berjumlah', nilai70Plus)

# standar deviasi
# maksimum
nilaiMaksimum = 1

for m in nilaiTugas:
    if m > nilaiMaksimum :
        nilaiMaksimum = m

print()
print('Nilai maksimum =', nilaiMaksimum)

# minimum
nilaiMinimum = 99

for m in nilaiTugas:
    if m < nilaiMinimum :
        nilaiMinimum = m

print()
print('Nilai minimum =', nilaiMinimum)

# modus
frekuensiNilai = []

for i in range(0,100) :
    frekuensiNilai.append(0)

for n in nilaiTugas :
    frekuensiNilai[n] += 1

frekuensiModus = 0

for f in frekuensiNilai :
    if f > frekuensiModus :
        frekuensiModus = f

modus = []

for i,f in enumerate(frekuensiNilai) :
    if f == frekuensiModus :
        modus.append(i)

print()
print('Modus dari sekumpulan nilai di atas adalah', modus)
# Out:
# [20, 41, 28, 22, 33, 89, 4, 97, 62, 88, 69, 39, 13, 2, 16, 32, 50, 81, 57, 7, 83, 55, 18, 74, 38, 9, 83, 77, 1, 94, 9, 55, 7, 93, 53, 8, 35, 11, 55, 11, 90, 61, 74, 55, 96, 9, 67, 32, 70, 96, 50, 90, 18, 26, 37, 25, 40, 6, 83, 70, 80, 78, 80, 49, 69, 40, 52, 33, 71, 9, 78, 91, 22, 77, 95, 57, 52, 82, 20, 63, 10, 57, 8, 61, 22, 52, 67, 72, 89, 36, 11, 89, 99, 11, 21, 96, 6, 45, 22, 38, 31, 79, 9, 36, 76, 4, 32, 81, 41, 95, 64, 46, 58, 82, 81, 13, 4, 70, 4, 32, 58, 87, 12, 97, 33, 29, 59, 23, 32, 66, 75, 3, 58, 49, 98, 26, 60, 75, 19, 59, 74, 90, 9, 99, 26, 66, 49, 89, 3, 33, 96, 5, 70, 10, 24, 65, 50, 94, 22, 31, 57, 16, 90, 93, 34, 26, 48, 22, 14, 78, 99, 6, 90, 52, 86, 13, 18, 53, 7, 77, 10, 46, 62, 54, 95, 39, 37, 45, 74, 99, 8, 38, 79, 56, 10, 38, 21, 88, 55, 31, 80, 3, 20, 86, 70, 70, 77, 41, 27, 44, 36, 30, 58, 47, 8, 68, 15, 41, 22, 65, 75, 70, 6, 43, 56, 56, 90, 74, 91, 85, 89, 53, 2, 66, 63, 15, 95, 22, 14, 52, 61, 31, 80, 92, 48, 69, 50, 87, 43, 85]
#
# Angka Ganjil dari ke 250 nilai di atas (angka yang sama hanya ditampilkan satu kali ) yaitu : [41, 33, 89, 97, 69, 39, 13, 81, 57, 7, 83, 55, 9, 77, 1, 93, 53, 35, 11, 61, 67, 37, 25, 49, 71, 91, 95, 63, 99, 21, 45, 31, 79, 87, 29, 59, 23, 75, 3, 19, 5, 65, 27, 47, 15, 43, 85]
#
# Yang mendapatkan nilai lebih dari 70 berjumlah 73
#
# Nilai maksimum = 99
#
# Nilai minimum = 1
#
# Modus dari sekumpulan nilai di atas adalah [22]
